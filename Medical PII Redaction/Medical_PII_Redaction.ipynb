# %%
# !pip install seaborn matplotlib codecarbon torch transformers statsmodels wordcloud statsmodels
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Collecting matplotlib
#   Using cached matplotlib-3.9.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
# Collecting codecarbon
#   Using cached codecarbon-2.5.0-py3-none-any.whl (496 kB)
# Collecting torch
#   Using cached torch-2.3.1-cp39-cp39-manylinux1_x86_64.whl (779.1 MB)
# Collecting transformers
#   Using cached transformers-4.41.2-py3-none-any.whl (9.1 MB)
# Collecting statsmodels
#   Using cached statsmodels-0.14.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/ray/anaconda3/lib/python3.9/site-packages (from seaborn) (1.24.4)
# Requirement already satisfied: pandas>=1.2 in /home/ray/anaconda3/lib/python3.9/site-packages (from seaborn) (1.5.3)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.2.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (304 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.0/305.0 kB 6.0 MB/s eta 0:00:00a 0:00:01
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.53.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 73.5 MB/s eta 0:00:00a 0:00:01
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.5-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 95.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /home/ray/anaconda3/lib/python3.9/site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in /home/ray/anaconda3/lib/python3.9/site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ray/anaconda3/lib/python3.9/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ray/anaconda3/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/ray/anaconda3/lib/python3.9/site-packages (from matplotlib) (6.4.0)
# Requirement already satisfied: arrow in /home/ray/anaconda3/lib/python3.9/site-packages (from codecarbon) (1.3.0)
# Requirement already satisfied: click in /home/ray/anaconda3/lib/python3.9/site-packages (from codecarbon) (8.1.7)
# Requirement already satisfied: prometheus-client in /home/ray/anaconda3/lib/python3.9/site-packages (from codecarbon) (0.19.0)
# Requirement already satisfied: psutil in /home/ray/anaconda3/lib/python3.9/site-packages (from codecarbon) (5.9.8)
# Collecting py-cpuinfo (from codecarbon)
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Collecting pynvml (from codecarbon)
#   Downloading pynvml-11.5.0-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 9.9 MB/s eta 0:00:00
# Collecting rapidfuzz (from codecarbon)
#   Downloading rapidfuzz-3.9.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 91.6 MB/s eta 0:00:00:00:01
# Requirement already satisfied: requests in /home/ray/anaconda3/lib/python3.9/site-packages (from codecarbon) (2.31.0)
# Requirement already satisfied: filelock in /home/ray/anaconda3/lib/python3.9/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/ray/anaconda3/lib/python3.9/site-packages (from torch) (4.8.0)
# Collecting sympy (from torch)
#   Using cached sympy-1.12.1-py3-none-any.whl (5.7 MB)
# Requirement already satisfied: networkx in /home/ray/anaconda3/lib/python3.9/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /home/ray/anaconda3/lib/python3.9/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /home/ray/anaconda3/lib/python3.9/site-packages (from torch) (2023.5.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Collecting triton==2.3.1 (from torch)
#   Using cached triton-2.3.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (168.1 MB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch)
#   Using cached nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
# Collecting huggingface-hub<1.0,>=0.23.0 (from transformers)
#   Using cached huggingface_hub-0.23.4-py3-none-any.whl (402 kB)
# Requirement already satisfied: pyyaml>=5.1 in /home/ray/anaconda3/lib/python3.9/site-packages (from transformers) (5.3.1)
# Collecting regex!=2019.12.17 (from transformers)
#   Using cached regex-2024.5.15-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (774 kB)
# Collecting tokenizers<0.20,>=0.19 (from transformers)
#   Using cached tokenizers-0.19.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
# Collecting safetensors>=0.4.1 (from transformers)
#   Using cached safetensors-0.4.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
# Requirement already satisfied: tqdm>=4.27 in /home/ray/anaconda3/lib/python3.9/site-packages (from transformers) (4.66.2)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /home/ray/anaconda3/lib/python3.9/site-packages (from statsmodels) (1.11.4)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Using cached patsy-0.5.6-py2.py3-none-any.whl (233 kB)
# Requirement already satisfied: zipp>=3.1.0 in /home/ray/anaconda3/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: pytz>=2020.1 in /home/ray/anaconda3/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2022.7.1)
# Requirement already satisfied: six in /home/ray/anaconda3/lib/python3.9/site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/ray/anaconda3/lib/python3.9/site-packages (from arrow->codecarbon) (2.9.0.20240316)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ray/anaconda3/lib/python3.9/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ray/anaconda3/lib/python3.9/site-packages (from requests->codecarbon) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/ray/anaconda3/lib/python3.9/site-packages (from requests->codecarbon) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ray/anaconda3/lib/python3.9/site-packages (from requests->codecarbon) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ray/anaconda3/lib/python3.9/site-packages (from requests->codecarbon) (2023.11.17)
# Collecting mpmath<1.4.0,>=1.1.0 (from sympy->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: py-cpuinfo, mpmath, triton, sympy, safetensors, regex, rapidfuzz, pynvml, patsy, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, kiwisolver, fonttools, cycler, contourpy, nvidia-cusparse-cu12, nvidia-cudnn-cu12, matplotlib, huggingface-hub, tokenizers, statsmodels, seaborn, nvidia-cusolver-cu12, codecarbon, transformers, torch
# Successfully installed codecarbon-2.5.0 contourpy-1.2.1 cycler-0.12.1 fonttools-4.53.0 huggingface-hub-0.23.4 kiwisolver-1.4.5 matplotlib-3.9.0 mpmath-1.3.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105 patsy-0.5.6 py-cpuinfo-9.0.0 pynvml-11.5.0 rapidfuzz-3.9.3 regex-2024.5.15 safetensors-0.4.3 seaborn-0.13.2 statsmodels-0.14.2 sympy-1.12.1 tokenizers-0.19.1 torch-2.3.1 transformers-4.41.2 triton-2.3.1
#
# [notice] A new release of pip is available: 23.1.2 -> 24.1.1
# [notice] To update, run: pip install --upgrade pip
# Found credentials from IAM Role: cld_sqtdzdr5mrcsnej9dlxzm17f7h-cluster-node-role

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import torch

# %matplotlib inline

# %% [markdown]
# ## Run Medical NER Transcription

# %%
df = pd.read_csv("/home/ray/default/20062024 anyscale repo/2016r_mtsamples_final.csv")

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline
pipe = pipeline("token-classification", model="Clinical-AI-Apollo/Medical-NER", aggregation_strategy='simple')
text='PREOPERATIVE DIAGNOSIS: , Morbid obesity. ,POSTOPERATIVE DIAGNOSIS: , Morbid obesity. ,PROCEDURE:, Laparoscopic Roux-en-Y gastric bypass, antecolic, antegastric with 25-mm EEA anastamosis, esophagogastroduodenoscopy. ,ANESTHESIA: , General with endotracheal intubation. ,INDICATIONS FOR PROCEDURE: , This is a 50-year-old male who has been overweight for many years and has tried multiple different weight loss diets and programs. The patient has now begun to have comorbidities related to the obesity. The patient has attended our bariatric seminar and met with our dietician and psychologist. The patient has read through our comprehensive handout and understands the risks and benefits of bypass surgery as evidenced by the signing of our consent form.,PROCEDURE IN DETAIL: , The risks and benefits were explained to the patient. Consent was obtained. The patient was taken to the operating room and placed supine on the operating room table. General anesthesia was administered with endotracheal intubation. A Foley catheter was placed for bladder decompression. All pressure points were carefully padded, and sequential compression devices were placed on the legs. The abdomen was prepped and draped in standard, sterile, surgical fashion. Marcaine was injected into the umbilicus'
result = pipe(text)



# Load model directly
from transformers import AutoTokenizer, AutoModelForTokenClassification

tokenizer = AutoTokenizer.from_pretrained("Clinical-AI-Apollo/Medical-NER")
model = AutoModelForTokenClassification.from_pretrained("Clinical-AI-Apollo/Medical-NER")
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.28k [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/8.66M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/23.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/286 [00:00<?, ?B/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.

# %% [markdown]
# ## Including Codecarbon

# %%
import pandas as pd
from transformers import pipeline
from codecarbon import EmissionsTracker

# Initialize the emissions tracker
tracker = EmissionsTracker(project_name="NER_Masking")

# Load the NER pipeline once to avoid reloading it every function call
ner_pipeline = pipeline("token-classification", model="Clinical-AI-Apollo/Medical-NER", aggregation_strategy='simple')

def mask_specific_entities(df, input_column, entity_groups_to_mask):
    # Function to mask entities in a single transcription
    def mask_text(text):
        entities = ner_pipeline(text)
        masked_text = text
        offset = 0
        for entity in sorted(entities, key=lambda x: x['start']):
            if entity['entity_group'].lower() in entity_groups_to_mask:
                start = entity['start'] + offset
                end = entity['end'] + offset
                entity_tag = entity['entity_group']
                masked_word = f"[{entity_tag}]"
                masked_text = masked_text[:start] + masked_word + masked_text[end:]
                offset += len(masked_word) - (end - start)

        return masked_text

    # Apply the masking function to each row in the specified column
    df['med_masked_transcriptions'] = df[input_column].apply(mask_text)
    return df

df = pd.DataFrame(df)
input_column = 'extracted_text'
entity_groups_to_mask = ['disease_disorder', 'sign_symptom', 'age', 'sex', 'lab_value']

if __name__ == "__main__":
    # Start tracking emissions
    tracker.start()
    
    # Process the DataFrame
    masked_df = mask_specific_entities(df, input_column, entity_groups_to_mask)
    
    # Stop tracking emissions
    tracker.stop()

    print(masked_df)
# Out:
# [codecarbon INFO @ 02:14:57] [setup] RAM Tracking...
# [codecarbon INFO @ 02:14:57] [setup] GPU Tracking...
# [codecarbon INFO @ 02:14:57] No GPU found.
# [codecarbon INFO @ 02:14:57] [setup] CPU Tracking...
# [codecarbon WARNING @ 02:14:57] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 02:14:58] CPU Model on constant consumption mode: Intel(R) Xeon(R) Platinum 8259CL CPU @ 2.50GHz
# [codecarbon INFO @ 02:14:58] >>> Tracker's metadata:
# [codecarbon INFO @ 02:14:58]   Platform system: Linux-6.5.0-1020-aws-x86_64-with-glibc2.31
# [codecarbon INFO @ 02:14:58]   Python version: 3.9.19
# [codecarbon INFO @ 02:14:58]   CodeCarbon version: 2.5.0
# [codecarbon INFO @ 02:14:58]   Available RAM : 30.971 GB
# [codecarbon INFO @ 02:14:58]   CPU count: 8
# [codecarbon INFO @ 02:14:58]   CPU model: Intel(R) Xeon(R) Platinum 8259CL CPU @ 2.50GHz
# [codecarbon INFO @ 02:14:58]   GPU count: None
# [codecarbon INFO @ 02:14:58]   GPU model: None
# [codecarbon INFO @ 02:14:59] Saving emissions data to file /home/ray/default/20062024 anyscale repo/emissions.csv
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# [codecarbon INFO @ 02:15:14] Energy consumed for RAM : 0.000048 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:15:14] Energy consumed for all CPUs : 0.000438 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:15:14] 0.000486 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:15:29] Energy consumed for RAM : 0.000097 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:15:29] Energy consumed for all CPUs : 0.000875 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:15:29] 0.000972 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:15:44] Energy consumed for RAM : 0.000145 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:15:44] Energy consumed for all CPUs : 0.001313 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:15:44] 0.001458 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:15:59] Energy consumed for RAM : 0.000194 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:15:59] Energy consumed for all CPUs : 0.001750 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:15:59] 0.001944 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:16:14] Energy consumed for RAM : 0.000242 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:16:14] Energy consumed for all CPUs : 0.002187 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:16:14] 0.002429 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:16:29] Energy consumed for RAM : 0.000290 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:16:29] Energy consumed for all CPUs : 0.002625 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:16:29] 0.002915 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:16:44] Energy consumed for RAM : 0.000339 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:16:44] Energy consumed for all CPUs : 0.003062 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:16:44] 0.003401 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:16:59] Energy consumed for RAM : 0.000387 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:16:59] Energy consumed for all CPUs : 0.003500 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:16:59] 0.003887 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:16:59] 0.021537 g.CO2eq/s mean an estimation of 679.1830241910409 kg.CO2eq/year
# [codecarbon INFO @ 02:17:14] Energy consumed for RAM : 0.000435 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:17:14] Energy consumed for all CPUs : 0.003937 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:17:14] 0.004373 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:17:29] Energy consumed for RAM : 0.000484 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:17:29] Energy consumed for all CPUs : 0.004375 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:17:29] 0.004859 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:17:44] Energy consumed for RAM : 0.000532 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:17:44] Energy consumed for all CPUs : 0.004812 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:17:44] 0.005344 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:17:59] Energy consumed for RAM : 0.000581 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:17:59] Energy consumed for all CPUs : 0.005250 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:17:59] 0.005830 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:18:14] Energy consumed for RAM : 0.000629 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:18:14] Energy consumed for all CPUs : 0.005687 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:18:14] 0.006316 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:18:29] Energy consumed for RAM : 0.000677 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:18:29] Energy consumed for all CPUs : 0.006125 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:18:29] 0.006802 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:18:44] Energy consumed for RAM : 0.000726 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:18:44] Energy consumed for all CPUs : 0.006562 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:18:44] 0.007288 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:18:59] Energy consumed for RAM : 0.000774 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:18:59] Energy consumed for all CPUs : 0.006999 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:18:59] 0.007774 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:18:59] 0.021537 g.CO2eq/s mean an estimation of 679.1789524541651 kg.CO2eq/year
# [codecarbon INFO @ 02:19:14] Energy consumed for RAM : 0.000822 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:19:14] Energy consumed for all CPUs : 0.007437 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:19:14] 0.008259 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:19:20] Energy consumed for RAM : 0.000842 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:19:20] Energy consumed for all CPUs : 0.007615 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:19:20] 0.008457 kWh of electricity used since the beginning.
#              medical_specialty  \
# 0                    Neurology
# 1     Cardiovascular/Pulmonary
# 2                      Urology
# 3                      Urology
# 4                      Urology
# ...                        ...
# 2011  Cardiovascular/Pulmonary
# 2012  Cardiovascular/Pulmonary
# 2013  Cardiovascular/Pulmonary
# 2014  Cardiovascular/Pulmonary
# 2015  Cardiovascular/Pulmonary
#
#                                           transcription  \
# 0     CC:, Confusion and slurred speech.,HX , (prima...
# 1     PREOPERATIVE DIAGNOSES,Airway obstruction seco...
# 2     PROCEDURE: , Elective male sterilization via b...
# 3     DESCRIPTION:,  The patient was placed in the s...
# 4     PREOPERATIVE DIAGNOSIS: , Voluntary sterility....
# ...                                                 ...
# 2011  INDICATION: , Chest pain.,TYPE OF TEST: , Aden...
# 2012  CHIEF COMPLAINT: , Chest pain.,HISTORY OF PRES...
# 2013  HISTORY OF PRESENT ILLNESS: , The patient is a...
# 2014  HISTORY OF PRESENT ILLNESS: , Mr. ABC is a 60-...
# 2015  REASON FOR CONSULTATION:  ,Abnormal echocardio...
#
#                                    age_related_sentence  \
# 0     HX , (primarily obtained from boyfriend): This...
# 1     INDICATIONS FOR SURGERY,The patient is a 50-ye...
# 2     PROCEDURE: , Elective male sterilization via b...
# 3     DESCRIPTION:, The patient was placed in the su...
# 4     INDICATIONS FOR PROCEDURE:  ,A gentleman who i...
# ...                                                 ...
# 2011  TYPE OF TEST: , Adenosine with nuclear scan as...
# 2012  HISTORY OF PRESENT ILLNESS:,  The patient is a...
# 2013  HISTORY OF PRESENT ILLNESS: , The patient is a...
# 2014  ABC is a 60-year-old gentleman who had a marke...
# 2015  HISTORY OF PRESENT ILLNESS: ,The patient is an...
#
#                                          extracted_text  word_count  \
# 0     (primarily obtained from boyfriend): This 31 y...          43
# 1     The patient is a 50-year-old white male with h...          72
# 2     Elective male sterilization via bilateral vase...          43
# 3     The patient was placed in the supine position ...          44
# 4     A gentleman who is here today requesting volun...          63
# ...                                                 ...         ...
# 2011  Adenosine with nuclear scan as the patient una...          41
# 2012  The patient is a 40-year-old white male who pr...          46
# 2013  HISTORY OF PRESENT ILLNESS: , The patient is a...          62
# 2014  ABC is a 60-year-old gentleman who had a marke...         119
# 2015  HISTORY OF PRESENT ILLNESS: ,The patient is an...          45
#
#                               med_masked_transcriptions
# 0     (primarily obtained from boyfriend): This[AGE]...
# 1     The patient is a[AGE] white[SEX] with history ...
# 2     Elective male sterilization via bilateral vase...
# 3     The patient was placed in the supine position ...
# 4     A gentleman who is here today requesting volun...
# ...                                                 ...
# 2011  Adenosine with nuclear scan as the patient una...
# 2012  The patient is a[AGE] white[SEX] who presents ...
# 2013  HISTORY OF PRESENT ILLNESS: , The patient is a...
# 2014  ABC is a[AGE][SEX] who had a[LAB_VALUE][LAB_VA...
# 2015  HISTORY OF PRESENT ILLNESS: ,The patient is an...
#
# [2016 rows x 6 columns]

# %% [markdown]
# ## PII Redaction integrated with codecarbon

# %%
import pandas as pd
from transformers import pipeline
from codecarbon import EmissionsTracker

# Initialize the emissions tracker
tracker = EmissionsTracker(project_name="PII_Redaction")

# Load the PII pipeline once to avoid reloading it every function call
pii_pipeline = pipeline("token-classification", model="Isotonic/deberta-v3-base_finetuned_ai4privacy_v2", aggregation_strategy='simple')

def redact_pii(df, input_column, pii_groups_to_mask):
    """
    Function to redact personally identifiable information (PII) from a DataFrame column using a specified PII NER model.

    Parameters:
    df: DataFrame containing the data to be processed.
    input_column: String specifying the column containing text to process.
    pii_groups_to_mask: List of PII entity groups to mask (e.g., ['SSN', 'CREDIT_CARD', 'PHONE_NUMBER']).

    Returns:
    DataFrame with an additional column 'pii_masked_transcriptions' containing the PII-redacted text.
    """
    def redact_text(text):
        pii_entities = pii_pipeline(text)
        pii_masked_text = text
        offset = 0
        for entity in sorted(pii_entities, key=lambda x: x['start']):
            if entity['entity_group'].lower() in pii_groups_to_mask:
                start = entity['start'] + offset
                end = entity['end'] + offset
                entity_tag = entity['entity_group']
                masked_word = f"[{entity_tag}]"
                pii_masked_text = pii_masked_text[:start] + masked_word + pii_masked_text[end:]
                offset += len(masked_word) - (end - start)

        return pii_masked_text

    # Apply the redaction function to each row in the specified column
    df['pii_masked_transcriptions'] = df[input_column].apply(redact_text)
    return df

df = pd.DataFrame(masked_df)
input_column = 'med_masked_transcriptions'
pii_groups_to_mask = ['city', 'state']

if __name__ == "__main__":
    # Start tracking emissions
    tracker.start()
    
    # Process the DataFrame
    pii_redacted_df = redact_pii(df, input_column, pii_groups_to_mask)
    
    # Stop tracking emissions
    tracker.stop()

    print(pii_redacted_df)
# Out:
# [codecarbon INFO @ 02:21:33] [setup] RAM Tracking...
# [codecarbon INFO @ 02:21:33] [setup] GPU Tracking...
# [codecarbon INFO @ 02:21:33] No GPU found.
# [codecarbon INFO @ 02:21:33] [setup] CPU Tracking...
# [codecarbon WARNING @ 02:21:33] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 02:21:34] CPU Model on constant consumption mode: Intel(R) Xeon(R) Platinum 8259CL CPU @ 2.50GHz
# [codecarbon INFO @ 02:21:34] >>> Tracker's metadata:
# [codecarbon INFO @ 02:21:34]   Platform system: Linux-6.5.0-1020-aws-x86_64-with-glibc2.31
# [codecarbon INFO @ 02:21:34]   Python version: 3.9.19
# [codecarbon INFO @ 02:21:34]   CodeCarbon version: 2.5.0
# [codecarbon INFO @ 02:21:34]   Available RAM : 30.971 GB
# [codecarbon INFO @ 02:21:34]   CPU count: 8
# [codecarbon INFO @ 02:21:34]   CPU model: Intel(R) Xeon(R) Platinum 8259CL CPU @ 2.50GHz
# [codecarbon INFO @ 02:21:34]   GPU count: None
# [codecarbon INFO @ 02:21:34]   GPU model: None
# [codecarbon INFO @ 02:21:34] Saving emissions data to file /home/ray/default/20062024 anyscale repo/emissions.csv
# config.json:   0%|          | 0.00/6.10k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/736M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.28k [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/8.66M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/23.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/286 [00:00<?, ?B/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# [codecarbon INFO @ 02:21:53] Energy consumed for RAM : 0.000048 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:21:53] Energy consumed for all CPUs : 0.000438 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:21:53] 0.000486 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:22:08] Energy consumed for RAM : 0.000097 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:22:08] Energy consumed for all CPUs : 0.000875 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:22:08] 0.000972 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:22:23] Energy consumed for RAM : 0.000145 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:22:23] Energy consumed for all CPUs : 0.001313 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:22:23] 0.001458 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:22:38] Energy consumed for RAM : 0.000194 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:22:38] Energy consumed for all CPUs : 0.001750 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:22:38] 0.001943 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:22:53] Energy consumed for RAM : 0.000242 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:22:53] Energy consumed for all CPUs : 0.002187 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:22:53] 0.002429 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:23:08] Energy consumed for RAM : 0.000290 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:23:08] Energy consumed for all CPUs : 0.002625 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:23:08] 0.002915 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:23:23] Energy consumed for RAM : 0.000339 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:23:23] Energy consumed for all CPUs : 0.003062 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:23:23] 0.003401 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:23:38] Energy consumed for RAM : 0.000387 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:23:38] Energy consumed for all CPUs : 0.003500 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:23:38] 0.003887 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:23:38] 0.021536 g.CO2eq/s mean an estimation of 679.1621386195002 kg.CO2eq/year
# [codecarbon INFO @ 02:23:53] Energy consumed for RAM : 0.000435 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:23:53] Energy consumed for all CPUs : 0.003937 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:23:53] 0.004373 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:24:08] Energy consumed for RAM : 0.000484 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:24:08] Energy consumed for all CPUs : 0.004375 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:24:08] 0.004858 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:24:23] Energy consumed for RAM : 0.000532 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:24:23] Energy consumed for all CPUs : 0.004812 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:24:23] 0.005344 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:24:38] Energy consumed for RAM : 0.000581 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:24:38] Energy consumed for all CPUs : 0.005250 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:24:38] 0.005830 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:24:53] Energy consumed for RAM : 0.000629 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:24:53] Energy consumed for all CPUs : 0.005687 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:24:53] 0.006316 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:25:08] Energy consumed for RAM : 0.000677 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:25:08] Energy consumed for all CPUs : 0.006125 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:25:08] 0.006802 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:25:23] Energy consumed for RAM : 0.000726 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:25:23] Energy consumed for all CPUs : 0.006562 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:25:23] 0.007288 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:25:38] Energy consumed for RAM : 0.000774 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:25:38] Energy consumed for all CPUs : 0.006999 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:25:38] 0.007774 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:25:38] 0.021537 g.CO2eq/s mean an estimation of 679.192352849413 kg.CO2eq/year
# [codecarbon INFO @ 02:25:53] Energy consumed for RAM : 0.000822 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:25:53] Energy consumed for all CPUs : 0.007437 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:25:53] 0.008259 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:26:08] Energy consumed for RAM : 0.000871 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:26:08] Energy consumed for all CPUs : 0.007874 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:26:08] 0.008745 kWh of electricity used since the beginning.
# [codecarbon INFO @ 02:26:10] Energy consumed for RAM : 0.000879 kWh. RAM Power : 11.614046573638918 W
# [codecarbon INFO @ 02:26:10] Energy consumed for all CPUs : 0.007946 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 02:26:10] 0.008825 kWh of electricity used since the beginning.
#              medical_specialty  \
# 0                    Neurology
# 1     Cardiovascular/Pulmonary
# 2                      Urology
# 3                      Urology
# 4                      Urology
# ...                        ...
# 2011  Cardiovascular/Pulmonary
# 2012  Cardiovascular/Pulmonary
# 2013  Cardiovascular/Pulmonary
# 2014  Cardiovascular/Pulmonary
# 2015  Cardiovascular/Pulmonary
#
#                                           transcription  \
# 0     CC:, Confusion and slurred speech.,HX , (prima...
# 1     PREOPERATIVE DIAGNOSES,Airway obstruction seco...
# 2     PROCEDURE: , Elective male sterilization via b...
# 3     DESCRIPTION:,  The patient was placed in the s...
# 4     PREOPERATIVE DIAGNOSIS: , Voluntary sterility....
# ...                                                 ...
# 2011  INDICATION: , Chest pain.,TYPE OF TEST: , Aden...
# 2012  CHIEF COMPLAINT: , Chest pain.,HISTORY OF PRES...
# 2013  HISTORY OF PRESENT ILLNESS: , The patient is a...
# 2014  HISTORY OF PRESENT ILLNESS: , Mr. ABC is a 60-...
# 2015  REASON FOR CONSULTATION:  ,Abnormal echocardio...
#
#                                    age_related_sentence  \
# 0     HX , (primarily obtained from boyfriend): This...
# 1     INDICATIONS FOR SURGERY,The patient is a 50-ye...
# 2     PROCEDURE: , Elective male sterilization via b...
# 3     DESCRIPTION:, The patient was placed in the su...
# 4     INDICATIONS FOR PROCEDURE:  ,A gentleman who i...
# ...                                                 ...
# 2011  TYPE OF TEST: , Adenosine with nuclear scan as...
# 2012  HISTORY OF PRESENT ILLNESS:,  The patient is a...
# 2013  HISTORY OF PRESENT ILLNESS: , The patient is a...
# 2014  ABC is a 60-year-old gentleman who had a marke...
# 2015  HISTORY OF PRESENT ILLNESS: ,The patient is an...
#
#                                          extracted_text  word_count  \
# 0     (primarily obtained from boyfriend): This 31 y...          43
# 1     The patient is a 50-year-old white male with h...          72
# 2     Elective male sterilization via bilateral vase...          43
# 3     The patient was placed in the supine position ...          44
# 4     A gentleman who is here today requesting volun...          63
# ...                                                 ...         ...
# 2011  Adenosine with nuclear scan as the patient una...          41
# 2012  The patient is a 40-year-old white male who pr...          46
# 2013  HISTORY OF PRESENT ILLNESS: , The patient is a...          62
# 2014  ABC is a 60-year-old gentleman who had a marke...         119
# 2015  HISTORY OF PRESENT ILLNESS: ,The patient is an...          45
#
#                               med_masked_transcriptions  \
# 0     (primarily obtained from boyfriend): This[AGE]...
# 1     The patient is a[AGE] white[SEX] with history ...
# 2     Elective male sterilization via bilateral vase...
# 3     The patient was placed in the supine position ...
# 4     A gentleman who is here today requesting volun...
# ...                                                 ...
# 2011  Adenosine with nuclear scan as the patient una...
# 2012  The patient is a[AGE] white[SEX] who presents ...
# 2013  HISTORY OF PRESENT ILLNESS: , The patient is a...
# 2014  ABC is a[AGE][SEX] who had a[LAB_VALUE][LAB_VA...
# 2015  HISTORY OF PRESENT ILLNESS: ,The patient is an...
#
#                               pii_masked_transcriptions
# 0     (primarily obtained from boyfriend): This[AGE]...
# 1     The patient is a[AGE] white[SEX] with history ...
# 2     Elective male sterilization via bilateral vase...
# 3     The patient was placed in the supine position ...
# 4     A gentleman who is here today requesting volun...
# ...                                                 ...
# 2011  Adenosine with nuclear scan as the patient una...
# 2012  The patient is a[AGE] white[SEX] who presents ...
# 2013  HISTORY OF PRESENT ILLNESS: , The patient is a...
# 2014  ABC is a[AGE][SEX] who had a[LAB_VALUE][LAB_VA...
# 2015  HISTORY OF PRESENT ILLNESS: ,The patient is an...
#
# [2016 rows x 7 columns]

# %% [markdown]
# ## Inbetween Output

# %%
# Specify the path to save the CSV file
file_path = '2016r_mtsamples_finalredacted.csv'

# Save the DataFrame to CSV
pii_redacted_df.to_csv(file_path, index=False)  # Setting index=False to avoid saving the index as a separate column

print(f"DataFrame is successfully saved to {file_path}")
# Out:
# DataFrame is successfully saved to 2016r_mtsamples_finalredacted.csv

# %% [markdown]
# ### Masked Entity Count for Risk Score

# %%
import pandas as pd
from collections import defaultdict
import re

def count_masked_entities(entry):
    # Dictionary to store the counts of each entity
    entity_count = defaultdict(int)
    # Find all occurrences of patterns that match the masked entity format
    entities = re.findall(r'\[[^\]]+\]', str(entry))
    for entity in entities:
        # Increment the count for each entity found
        entity_count[entity] += 1
    return dict(entity_count)

def add_entity_count_column(df, column):
    # Apply the count_masked_entities function to each row in the specified column
    df['entity count'] = df[column].apply(count_masked_entities)
    return df

# Example usage:
# Assuming you have a DataFrame `df` and you are interested in the column 'transcriptions'
df = pd.DataFrame({
    'transcriptions': [
        "Patient has [disease_disorder] and is [age] years old.",
        "There is no indication of [disease_disorder] for the patient aged [age].",
        "Normal conditions, no [disease_disorder] detected.",
        None
    ]
})

# %%
# Add the new column with the entity counts
df2 = add_entity_count_column(masked_df, 'pii_masked_transcriptions')

# %% [markdown]
# ## Medical NER Control Set up

# %%
from huggingface_hub import login
login()

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForTokenClassification

tokenizer = AutoTokenizer.from_pretrained("d4data/biomedical-ner-all")
model = AutoModelForTokenClassification.from_pretrained("d4data/biomedical-ner-all")
# Out:
# tokenizer_config.json:   0%|          | 0.00/373 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/5.00k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/266M [00:00<?, ?B/s]

# %%
import pandas as pd
from transformers import pipeline
from codecarbon import EmissionsTracker

# Initialize the emissions tracker
tracker = EmissionsTracker(project_name="NER_Masking")

# Load the NER pipeline once to avoid reloading it every function call
ner_pipeline = pipeline("token-classification", model="d4data/biomedical-ner-all", aggregation_strategy='simple')

def mask_specific_entities(df, input_column, entity_groups_to_mask):
    # Function to mask entities in a single transcription
    def mask_text(text):
        entities = ner_pipeline(text)
        masked_text = text
        offset = 0
        for entity in sorted(entities, key=lambda x: x['start']):
            if entity['entity_group'].lower() in entity_groups_to_mask:
                start = entity['start'] + offset
                end = entity['end'] + offset
                entity_tag = entity['entity_group']
                masked_word = f"[{entity_tag}]"
                masked_text = masked_text[:start] + masked_word + masked_text[end:]
                offset += len(masked_word) - (end - start)

        return masked_text

    # Apply the masking function to each row in the specified column
    df['med_masked_transcriptions_biomedicalNER'] = df[input_column].apply(mask_text)
    return df

input_column = 'extracted_text'
entity_groups_to_mask = ['disease_disorder', 'sign_symptom', 'age', 'sex', 'lab_value']

if __name__ == "__main__":
    # Start tracking emissions
    tracker.start()
    
    # Process the DataFrame
    masked_df = mask_specific_entities(df, input_column, entity_groups_to_mask)
    
    # Stop tracking emissions
    tracker.stop()

    print(masked_df)
# Out:
# [codecarbon INFO @ 04:00:45] [setup] RAM Tracking...
# [codecarbon INFO @ 04:00:46] [setup] GPU Tracking...
# [codecarbon INFO @ 04:00:46] No GPU found.
# [codecarbon INFO @ 04:00:46] [setup] CPU Tracking...
# [codecarbon WARNING @ 04:00:46] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 04:00:47] CPU Model on constant consumption mode: Intel(R) Xeon(R) Platinum 8259CL CPU @ 2.50GHz
# [codecarbon INFO @ 04:00:47] >>> Tracker's metadata:
# [codecarbon INFO @ 04:00:47]   Platform system: Linux-6.5.0-1020-aws-x86_64-with-glibc2.31
# [codecarbon INFO @ 04:00:47]   Python version: 3.9.19
# [codecarbon INFO @ 04:00:47]   CodeCarbon version: 2.5.0
# [codecarbon INFO @ 04:00:47]   Available RAM : 30.971 GB
# [codecarbon INFO @ 04:00:47]   CPU count: 8
# [codecarbon INFO @ 04:00:47]   CPU model: Intel(R) Xeon(R) Platinum 8259CL CPU @ 2.50GHz
# [codecarbon INFO @ 04:00:47]   GPU count: None
# [codecarbon INFO @ 04:00:47]   GPU model: None
# [codecarbon INFO @ 04:00:47] Saving emissions data to file /home/ray/default/20062024 anyscale repo/emissions.csv
# [codecarbon INFO @ 04:01:02] Energy consumed for RAM : 0.000048 kWh. RAM Power : 11.61404800415039 W
# [codecarbon INFO @ 04:01:02] Energy consumed for all CPUs : 0.000438 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 04:01:02] 0.000486 kWh of electricity used since the beginning.
# [codecarbon INFO @ 04:01:17] Energy consumed for RAM : 0.000097 kWh. RAM Power : 11.61404800415039 W
# [codecarbon INFO @ 04:01:17] Energy consumed for all CPUs : 0.000875 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 04:01:17] 0.000972 kWh of electricity used since the beginning.
# [codecarbon INFO @ 04:01:32] Energy consumed for RAM : 0.000145 kWh. RAM Power : 11.61404800415039 W
# [codecarbon INFO @ 04:01:32] Energy consumed for all CPUs : 0.001313 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 04:01:32] 0.001458 kWh of electricity used since the beginning.
# [codecarbon INFO @ 04:01:47] Energy consumed for RAM : 0.000194 kWh. RAM Power : 11.61404800415039 W
# [codecarbon INFO @ 04:01:47] Energy consumed for all CPUs : 0.001750 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 04:01:47] 0.001943 kWh of electricity used since the beginning.
# [codecarbon INFO @ 04:02:02] Energy consumed for RAM : 0.000242 kWh. RAM Power : 11.61404800415039 W
# [codecarbon INFO @ 04:02:02] Energy consumed for all CPUs : 0.002187 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 04:02:02] 0.002429 kWh of electricity used since the beginning.
# [codecarbon INFO @ 04:02:09] Energy consumed for RAM : 0.000266 kWh. RAM Power : 11.61404800415039 W
# [codecarbon INFO @ 04:02:09] Energy consumed for all CPUs : 0.002401 kWh. Total CPU Power : 105.0 W
# [codecarbon INFO @ 04:02:09] 0.002666 kWh of electricity used since the beginning.
#              medical_specialty  \
# 0                    Neurology
# 1     Cardiovascular/Pulmonary
# 2                      Urology
# 3                      Urology
# 4                      Urology
# ...                        ...
# 2011  Cardiovascular/Pulmonary
# 2012  Cardiovascular/Pulmonary
# 2013  Cardiovascular/Pulmonary
# 2014  Cardiovascular/Pulmonary
# 2015  Cardiovascular/Pulmonary
#
#                                           transcription  \
# 0     CC:, Confusion and slurred speech.,HX , (prima...
# 1     PREOPERATIVE DIAGNOSES,Airway obstruction seco...
# 2     PROCEDURE: , Elective male sterilization via b...
# 3     DESCRIPTION:,  The patient was placed in the s...
# 4     PREOPERATIVE DIAGNOSIS: , Voluntary sterility....
# ...                                                 ...
# 2011  INDICATION: , Chest pain.,TYPE OF TEST: , Aden...
# 2012  CHIEF COMPLAINT: , Chest pain.,HISTORY OF PRES...
# 2013  HISTORY OF PRESENT ILLNESS: , The patient is a...
# 2014  HISTORY OF PRESENT ILLNESS: , Mr. ABC is a 60-...
# 2015  REASON FOR CONSULTATION:  ,Abnormal echocardio...
#
#                                    age_related_sentence  \
# 0     HX , (primarily obtained from boyfriend): This...
# 1     INDICATIONS FOR SURGERY,The patient is a 50-ye...
# 2     PROCEDURE: , Elective male sterilization via b...
# 3     DESCRIPTION:, The patient was placed in the su...
# 4     INDICATIONS FOR PROCEDURE:  ,A gentleman who i...
# ...                                                 ...
# 2011  TYPE OF TEST: , Adenosine with nuclear scan as...
# 2012  HISTORY OF PRESENT ILLNESS:,  The patient is a...
# 2013  HISTORY OF PRESENT ILLNESS: , The patient is a...
# 2014  ABC is a 60-year-old gentleman who had a marke...
# 2015  HISTORY OF PRESENT ILLNESS: ,The patient is an...
#
#                                          extracted_text  word_count  \
# 0     (primarily obtained from boyfriend): This 31 y...          43
# 1     The patient is a 50-year-old white male with h...          72
# 2     Elective male sterilization via bilateral vase...          43
# 3     The patient was placed in the supine position ...          44
# 4     A gentleman who is here today requesting volun...          63
# ...                                                 ...         ...
# 2011  Adenosine with nuclear scan as the patient una...          41
# 2012  The patient is a 40-year-old white male who pr...          46
# 2013  HISTORY OF PRESENT ILLNESS: , The patient is a...          62
# 2014  ABC is a 60-year-old gentleman who had a marke...         119
# 2015  HISTORY OF PRESENT ILLNESS: ,The patient is an...          45
#
#                               med_masked_transcriptions  \
# 0     (primarily obtained from boyfriend): This[AGE]...
# 1     The patient is a[AGE] white[SEX] with history ...
# 2     Elective male sterilization via bilateral vase...
# 3     The patient was placed in the supine position ...
# 4     A gentleman who is here today requesting volun...
# ...                                                 ...
# 2011  Adenosine with nuclear scan as the patient una...
# 2012  The patient is a[AGE] white[SEX] who presents ...
# 2013  HISTORY OF PRESENT ILLNESS: , The patient is a...
# 2014  ABC is a[AGE][SEX] who had a[LAB_VALUE][LAB_VA...
# 2015  HISTORY OF PRESENT ILLNESS: ,The patient is an...
#
#                               pii_masked_transcriptions  \
# 0     (primarily obtained from boyfriend): This[AGE]...
# 1     The patient is a[AGE] white[SEX] with history ...
# 2     Elective male sterilization via bilateral vase...
# 3     The patient was placed in the supine position ...
# 4     A gentleman who is here today requesting volun...
# ...                                                 ...
# 2011  Adenosine with nuclear scan as the patient una...
# 2012  The patient is a[AGE] white[SEX] who presents ...
# 2013  HISTORY OF PRESENT ILLNESS: , The patient is a...
# 2014  ABC is a[AGE][SEX] who had a[LAB_VALUE][LAB_VA...
# 2015  HISTORY OF PRESENT ILLNESS: ,The patient is an...
#
#                  synthetic_sentence_nodp_temp0.6_topk50  \
# 0     [BOS]Neurology[SEP]The patient is a 55-year-ol...
# 1     [BOS]Cardiovascular/Pulmonary[SEP]This is a 74...
# 2     [BOS]Urology[SEP]HISTORY OF PRESENT ILLNESS:, ...
# 3     [BOS]Urology[SEP]The patient was brought to th...
# 4     [BOS]Urology[SEP]The patient was brought to th...
# ...                                                 ...
# 2011  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2012  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2013  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2014  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2015  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
#
#                   synthetic_sentence_eps16_temp1_topk50  \
# 0     [BOS]Neurology[SEP]The patient is a 38-year-ol...
# 1     [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2     [BOS]Urology[SEP]Cardiovascular/Pulmonary[SEP:...
# 3     [BOS]Urology[SEP]The patient with a history of...
# 4     [BOS]Urology[SEP]HISTORY OF THE PROCEDURE:, Th...
# ...                                                 ...
# 2011  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2012  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2013  [BOS]Cardiovascular/Pulmonary[SEP]This is a 5-...
# 2014  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2015  [BOS]Cardiovascular/Pulmonary[SEP]This is a 35...
#
#                   synthetic_sentence_eps8_temp1_topk100  \
# 0     [BOS]Neurology[SEP]Shitetron[SEPSEP]The patien...
# 1     [BOS]Cardiovascular/Pulmonary[SEP]This is a yo...
# 2     [BOS]Urology[SEP]HISTORY OF DISHISTORY AND BEE...
# 3     [BOS]Urology[SEP]Ophytology[SEPURE] The patien...
# 4     [BOS]Urology[SEP]The patient is a 1-year-old f...
# ...                                                 ...
# 2011  [BOS]Cardiovascular/Pulmonary[SEP]Pulmonary/Ho...
# 2012  [BOS]Cardiovascular/Pulmonary[SEP]After the pr...
# 2013  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2014  [BOS]Cardiovascular/Pulmonary[SEP]Overmed. The...
# 2015  [BOS]Cardiovascular/Pulmonary[SEP]FF.UHOSSEP]T...
#
#                   synthetic_sentence_eps3_temp1_topk100  \
# 0     [BOS]Neurology[SEP]The patient is a 42-year-ol...
# 1     [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2     [BOS]Urology[SEP]This is a 38-year-old with a ...
# 3     [BOS]Urology[SEP]The patient is referred to a ...
# 4     [BOS]Urology[SEP]Neurology[SEPUE]Neuroptic[SEP...
# ...                                                 ...
# 2011  [BOS]Cardiovascular/Pulmonary[SEP]Ostomatic[SE...
# 2012  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2013  [BOS]Cardiovascular/Pulmonary[SEP]Omenopausal[...
# 2014  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2015  [BOS]Cardiovascular/Pulmonary[SEP]On the patie...
#
#                  synthetic_sentence_nodp_temp0.8_topk50  \
# 0     [BOS]Neurology[SEP]The patient is a 74-year-ol...
# 1     [BOS]Cardiovascular/Pulmonary[SEP]After inform...
# 2     [BOS]Urology[SEP]The patient was brought to th...
# 3     [BOS]Urology[SEP]The patient was brought to th...
# 4     [BOS]Urology[SEP]This is a 59-year-old boy who...
# ...                                                 ...
# 2011  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2012  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2013  [BOS]Cardiovascular/Pulmonary[SEP]This is a 74...
# 2014  [BOS]Cardiovascular/Pulmonary[SEP]This is a 13...
# 2015  [BOS]Cardiovascular/Pulmonary[SEP]HISTORY AND ...
#
#                  synthetic_sentence_nodp_temp1.0_topk50  \
# 0     [BOS]Neurology[SEP]He is performing missionary...
# 1     [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2     [BOS]Urology[SEP]HISTORY OF PRESENT ILLNESS:, ...
# 3     [BOS]Urology[SEP]The patient is a 78-year-old ...
# 4     [BOS]Urology[SEP]This is a 3-year-old infant w...
# ...                                                 ...
# 2011  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2012  [BOS]Cardiovascular/Pulmonary[SEP]With the pat...
# 2013  [BOS]Cardiovascular/Pulmonary[SEP]This is a 56...
# 2014  [BOS]Cardiovascular/Pulmonary[SEP]This is an 1...
# 2015  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
#
#                  synthetic_sentence_nodp_temp1.2_topk50  \
# 0     [BOS]Neurology[SEP]HISTORY OF PRESENT ILLNESS:...
# 1     [BOS]Cardiovascular/Pulmonary[SEP]This is 3-we...
# 2     [BOS]Urology[SEP]The patient had a routine con...
# 3     [BOS]Urology[SEP]This 58 y/o boy fell on this ...
# 4     [BOS]Urology[SEP]The patient was taken by stab...
# ...                                                 ...
# 2011  [BOS]Cardiovascular/Pulmonary[SEP]This is a 79...
# 2012  [BOS]Cardiovascular/Pulmonary[SEP]HISTORY OF P...
# 2013  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2014  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2015  [BOS]Cardiovascular/Pulmonary[SEP]The patient'...
#
#                 synthetic_sentence_nodp_temp1.2_topk100  \
# 0     [BOS]Neurology[SEP]Patient was transferred on ...
# 1     [BOS]Cardiovascular/Pulmonary[SEP]O patient, w...
# 2     [BOS]Urology[SEP]The patient, who fell well un...
# 3     [BOS]Urology[SEP]ABC experienced difficulty wh...
# 4     [BOS]Urology[SEP]After informed consent, the p...
# ...                                                 ...
# 2011  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2012  [BOS]Cardiovascular/Pulmonary[SEP]U to our mot...
# 2013  [BOS]Cardiovascular/Pulmonary[SEP]After inform...
# 2014  [BOS]Cardiovascular/Pulmonary[SEP]HISTORY OF T...
# 2015  [BOS]Cardiovascular/Pulmonary[SEP]MRI LEFT ANK...
#
#                 synthetic_sentence_nodp_temp1.0_topk100  \
# 0     [BOS]Neurology[SEP]The patient presents to the...
# 1     [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2     [BOS]Urology[SEP]The patient's room and brough...
# 3     [BOS]Urology[SEP]The patient tolerated the pro...
# 4     [BOS]Urology[SEP]The patient brought to the op...
# ...                                                 ...
# 2011  [BOS]Cardiovascular/Pulmonary[SEP]After inform...
# 2012  [BOS]Cardiovascular/Pulmonary[SEP] The patient...
# 2013  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2014  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2015  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
#
#                 synthetic_sentence_nodp_temp0.8_topk100  \
# 0     [BOS]Neurology[SEP]A 16-year-old female who wa...
# 1     [BOS]Cardiovascular/Pulmonary[SEP]After inform...
# 2     [BOS]Urology[SEP]The patient was brought to th...
# 3     [BOS]Urology[SEP]This is a 52-year-old male wh...
# 4     [BOS]Urology[SEP]The patient is a 57-year-old ...
# ...                                                 ...
# 2011  [BOS]Cardiovascular/Pulmonary[SEP]She had apha...
# 2012  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2013  [BOS]Cardiovascular/Pulmonary[SEP]This patient...
# 2014  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2015  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
#
#                 synthetic_sentence_nodp_temp0.6_topk100  \
# 0     [BOS]Neurology[SEP]The patient was brought to ...
# 1     [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2     [BOS]Urology[SEP]The patient is a 53-year-old ...
# 3     [BOS]Urology[SEP]The patient was brought in th...
# 4     [BOS]Urology[SEP]HISTORY OF PRESENT ILLNESS:,T...
# ...                                                 ...
# 2011  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2012  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2013  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2014  [BOS]Cardiovascular/Pulmonary[SEP]This is a 57...
# 2015  [BOS]Cardiovascular/Pulmonary[SEP]This is a 56...
#
#                 med_masked_transcriptions_biomedicalNER
# 0     (primarily obtained from boyfriend): This [Lab...
# 1     The patient is a [Age] white [Sex] with histor...
# 2     Elective [Sex] sterilization via bilateral vas...
# 3     The patient was placed in the supine position ...
# 4     A [Sex] who is here today requesting voluntary...
# ...                                                 ...
# 2011  Adenosine with nuclear scan as the patient [Si...
# 2012  The patient is a [Age] white [Sex] who present...
# 2013  HISTORY OF PRESENT ILLNESS: , The patient is a...
# 2014  ABC is a [Age] [Sex] who had a markedly [Lab_v...
# 2015  HISTORY OF PRESENT ILLNESS: ,The patient is an...
#
# [2016 rows x 19 columns]

# %%
masked_df
# Out:
#              medical_specialty  \
# 0                    Neurology
# 1     Cardiovascular/Pulmonary
# 2                      Urology
# 3                      Urology
# 4                      Urology
# ...                        ...
# 2011  Cardiovascular/Pulmonary
# 2012  Cardiovascular/Pulmonary
# 2013  Cardiovascular/Pulmonary
# 2014  Cardiovascular/Pulmonary
# 2015  Cardiovascular/Pulmonary
#
#                                           transcription  \
# 0     CC:, Confusion and slurred speech.,HX , (prima...
# 1     PREOPERATIVE DIAGNOSES,Airway obstruction seco...
# 2     PROCEDURE: , Elective male sterilization via b...
# 3     DESCRIPTION:,  The patient was placed in the s...
# 4     PREOPERATIVE DIAGNOSIS: , Voluntary sterility....
# ...                                                 ...
# 2011  INDICATION: , Chest pain.,TYPE OF TEST: , Aden...
# 2012  CHIEF COMPLAINT: , Chest pain.,HISTORY OF PRES...
# 2013  HISTORY OF PRESENT ILLNESS: , The patient is a...
# 2014  HISTORY OF PRESENT ILLNESS: , Mr. ABC is a 60-...
# 2015  REASON FOR CONSULTATION:  ,Abnormal echocardio...
#
#                                    age_related_sentence  \
# 0     HX , (primarily obtained from boyfriend): This...
# 1     INDICATIONS FOR SURGERY,The patient is a 50-ye...
# 2     PROCEDURE: , Elective male sterilization via b...
# 3     DESCRIPTION:, The patient was placed in the su...
# 4     INDICATIONS FOR PROCEDURE:  ,A gentleman who i...
# ...                                                 ...
# 2011  TYPE OF TEST: , Adenosine with nuclear scan as...
# 2012  HISTORY OF PRESENT ILLNESS:,  The patient is a...
# 2013  HISTORY OF PRESENT ILLNESS: , The patient is a...
# 2014  ABC is a 60-year-old gentleman who had a marke...
# 2015  HISTORY OF PRESENT ILLNESS: ,The patient is an...
#
#                                          extracted_text  word_count  \
# 0     (primarily obtained from boyfriend): This 31 y...          43
# 1     The patient is a 50-year-old white male with h...          72
# 2     Elective male sterilization via bilateral vase...          43
# 3     The patient was placed in the supine position ...          44
# 4     A gentleman who is here today requesting volun...          63
# ...                                                 ...         ...
# 2011  Adenosine with nuclear scan as the patient una...          41
# 2012  The patient is a 40-year-old white male who pr...          46
# 2013  HISTORY OF PRESENT ILLNESS: , The patient is a...          62
# 2014  ABC is a 60-year-old gentleman who had a marke...         119
# 2015  HISTORY OF PRESENT ILLNESS: ,The patient is an...          45
#
#                               med_masked_transcriptions  \
# 0     (primarily obtained from boyfriend): This[AGE]...
# 1     The patient is a[AGE] white[SEX] with history ...
# 2     Elective male sterilization via bilateral vase...
# 3     The patient was placed in the supine position ...
# 4     A gentleman who is here today requesting volun...
# ...                                                 ...
# 2011  Adenosine with nuclear scan as the patient una...
# 2012  The patient is a[AGE] white[SEX] who presents ...
# 2013  HISTORY OF PRESENT ILLNESS: , The patient is a...
# 2014  ABC is a[AGE][SEX] who had a[LAB_VALUE][LAB_VA...
# 2015  HISTORY OF PRESENT ILLNESS: ,The patient is an...
#
#                               pii_masked_transcriptions  \
# 0     (primarily obtained from boyfriend): This[AGE]...
# 1     The patient is a[AGE] white[SEX] with history ...
# 2     Elective male sterilization via bilateral vase...
# 3     The patient was placed in the supine position ...
# 4     A gentleman who is here today requesting volun...
# ...                                                 ...
# 2011  Adenosine with nuclear scan as the patient una...
# 2012  The patient is a[AGE] white[SEX] who presents ...
# 2013  HISTORY OF PRESENT ILLNESS: , The patient is a...
# 2014  ABC is a[AGE][SEX] who had a[LAB_VALUE][LAB_VA...
# 2015  HISTORY OF PRESENT ILLNESS: ,The patient is an...
#
#                  synthetic_sentence_nodp_temp0.6_topk50  \
# 0     [BOS]Neurology[SEP]The patient is a 55-year-ol...
# 1     [BOS]Cardiovascular/Pulmonary[SEP]This is a 74...
# 2     [BOS]Urology[SEP]HISTORY OF PRESENT ILLNESS:, ...
# 3     [BOS]Urology[SEP]The patient was brought to th...
# 4     [BOS]Urology[SEP]The patient was brought to th...
# ...                                                 ...
# 2011  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2012  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2013  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2014  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2015  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
#
#                   synthetic_sentence_eps16_temp1_topk50  \
# 0     [BOS]Neurology[SEP]The patient is a 38-year-ol...
# 1     [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2     [BOS]Urology[SEP]Cardiovascular/Pulmonary[SEP:...
# 3     [BOS]Urology[SEP]The patient with a history of...
# 4     [BOS]Urology[SEP]HISTORY OF THE PROCEDURE:, Th...
# ...                                                 ...
# 2011  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2012  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2013  [BOS]Cardiovascular/Pulmonary[SEP]This is a 5-...
# 2014  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2015  [BOS]Cardiovascular/Pulmonary[SEP]This is a 35...
#
#                   synthetic_sentence_eps8_temp1_topk100  \
# 0     [BOS]Neurology[SEP]Shitetron[SEPSEP]The patien...
# 1     [BOS]Cardiovascular/Pulmonary[SEP]This is a yo...
# 2     [BOS]Urology[SEP]HISTORY OF DISHISTORY AND BEE...
# 3     [BOS]Urology[SEP]Ophytology[SEPURE] The patien...
# 4     [BOS]Urology[SEP]The patient is a 1-year-old f...
# ...                                                 ...
# 2011  [BOS]Cardiovascular/Pulmonary[SEP]Pulmonary/Ho...
# 2012  [BOS]Cardiovascular/Pulmonary[SEP]After the pr...
# 2013  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2014  [BOS]Cardiovascular/Pulmonary[SEP]Overmed. The...
# 2015  [BOS]Cardiovascular/Pulmonary[SEP]FF.UHOSSEP]T...
#
#                   synthetic_sentence_eps3_temp1_topk100  \
# 0     [BOS]Neurology[SEP]The patient is a 42-year-ol...
# 1     [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2     [BOS]Urology[SEP]This is a 38-year-old with a ...
# 3     [BOS]Urology[SEP]The patient is referred to a ...
# 4     [BOS]Urology[SEP]Neurology[SEPUE]Neuroptic[SEP...
# ...                                                 ...
# 2011  [BOS]Cardiovascular/Pulmonary[SEP]Ostomatic[SE...
# 2012  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2013  [BOS]Cardiovascular/Pulmonary[SEP]Omenopausal[...
# 2014  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2015  [BOS]Cardiovascular/Pulmonary[SEP]On the patie...
#
#                  synthetic_sentence_nodp_temp0.8_topk50  \
# 0     [BOS]Neurology[SEP]The patient is a 74-year-ol...
# 1     [BOS]Cardiovascular/Pulmonary[SEP]After inform...
# 2     [BOS]Urology[SEP]The patient was brought to th...
# 3     [BOS]Urology[SEP]The patient was brought to th...
# 4     [BOS]Urology[SEP]This is a 59-year-old boy who...
# ...                                                 ...
# 2011  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2012  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2013  [BOS]Cardiovascular/Pulmonary[SEP]This is a 74...
# 2014  [BOS]Cardiovascular/Pulmonary[SEP]This is a 13...
# 2015  [BOS]Cardiovascular/Pulmonary[SEP]HISTORY AND ...
#
#                  synthetic_sentence_nodp_temp1.0_topk50  \
# 0     [BOS]Neurology[SEP]He is performing missionary...
# 1     [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2     [BOS]Urology[SEP]HISTORY OF PRESENT ILLNESS:, ...
# 3     [BOS]Urology[SEP]The patient is a 78-year-old ...
# 4     [BOS]Urology[SEP]This is a 3-year-old infant w...
# ...                                                 ...
# 2011  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2012  [BOS]Cardiovascular/Pulmonary[SEP]With the pat...
# 2013  [BOS]Cardiovascular/Pulmonary[SEP]This is a 56...
# 2014  [BOS]Cardiovascular/Pulmonary[SEP]This is an 1...
# 2015  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
#
#                  synthetic_sentence_nodp_temp1.2_topk50  \
# 0     [BOS]Neurology[SEP]HISTORY OF PRESENT ILLNESS:...
# 1     [BOS]Cardiovascular/Pulmonary[SEP]This is 3-we...
# 2     [BOS]Urology[SEP]The patient had a routine con...
# 3     [BOS]Urology[SEP]This 58 y/o boy fell on this ...
# 4     [BOS]Urology[SEP]The patient was taken by stab...
# ...                                                 ...
# 2011  [BOS]Cardiovascular/Pulmonary[SEP]This is a 79...
# 2012  [BOS]Cardiovascular/Pulmonary[SEP]HISTORY OF P...
# 2013  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2014  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2015  [BOS]Cardiovascular/Pulmonary[SEP]The patient'...
#
#                 synthetic_sentence_nodp_temp1.2_topk100  \
# 0     [BOS]Neurology[SEP]Patient was transferred on ...
# 1     [BOS]Cardiovascular/Pulmonary[SEP]O patient, w...
# 2     [BOS]Urology[SEP]The patient, who fell well un...
# 3     [BOS]Urology[SEP]ABC experienced difficulty wh...
# 4     [BOS]Urology[SEP]After informed consent, the p...
# ...                                                 ...
# 2011  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2012  [BOS]Cardiovascular/Pulmonary[SEP]U to our mot...
# 2013  [BOS]Cardiovascular/Pulmonary[SEP]After inform...
# 2014  [BOS]Cardiovascular/Pulmonary[SEP]HISTORY OF T...
# 2015  [BOS]Cardiovascular/Pulmonary[SEP]MRI LEFT ANK...
#
#                 synthetic_sentence_nodp_temp1.0_topk100  \
# 0     [BOS]Neurology[SEP]The patient presents to the...
# 1     [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2     [BOS]Urology[SEP]The patient's room and brough...
# 3     [BOS]Urology[SEP]The patient tolerated the pro...
# 4     [BOS]Urology[SEP]The patient brought to the op...
# ...                                                 ...
# 2011  [BOS]Cardiovascular/Pulmonary[SEP]After inform...
# 2012  [BOS]Cardiovascular/Pulmonary[SEP] The patient...
# 2013  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2014  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2015  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
#
#                 synthetic_sentence_nodp_temp0.8_topk100  \
# 0     [BOS]Neurology[SEP]A 16-year-old female who wa...
# 1     [BOS]Cardiovascular/Pulmonary[SEP]After inform...
# 2     [BOS]Urology[SEP]The patient was brought to th...
# 3     [BOS]Urology[SEP]This is a 52-year-old male wh...
# 4     [BOS]Urology[SEP]The patient is a 57-year-old ...
# ...                                                 ...
# 2011  [BOS]Cardiovascular/Pulmonary[SEP]She had apha...
# 2012  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2013  [BOS]Cardiovascular/Pulmonary[SEP]This patient...
# 2014  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2015  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
#
#                 synthetic_sentence_nodp_temp0.6_topk100  \
# 0     [BOS]Neurology[SEP]The patient was brought to ...
# 1     [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2     [BOS]Urology[SEP]The patient is a 53-year-old ...
# 3     [BOS]Urology[SEP]The patient was brought in th...
# 4     [BOS]Urology[SEP]HISTORY OF PRESENT ILLNESS:,T...
# ...                                                 ...
# 2011  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2012  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2013  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2014  [BOS]Cardiovascular/Pulmonary[SEP]This is a 57...
# 2015  [BOS]Cardiovascular/Pulmonary[SEP]This is a 56...
#
#                 med_masked_transcriptions_biomedicalNER
# 0     (primarily obtained from boyfriend): This [Lab...
# 1     The patient is a [Age] white [Sex] with histor...
# 2     Elective [Sex] sterilization via bilateral vas...
# 3     The patient was placed in the supine position ...
# 4     A [Sex] who is here today requesting voluntary...
# ...                                                 ...
# 2011  Adenosine with nuclear scan as the patient [Si...
# 2012  The patient is a [Age] white [Sex] who present...
# 2013  HISTORY OF PRESENT ILLNESS: , The patient is a...
# 2014  ABC is a [Age] [Sex] who had a markedly [Lab_v...
# 2015  HISTORY OF PRESENT ILLNESS: ,The patient is an...
#
# [2016 rows x 19 columns]

# %%
from transformers import pipeline
import pandas as pd
from huggingface_hub import login

# Use the specified PII model
pii_pipeline = pipeline("token-classification", model="ab-ai/pii_model", aggregation_strategy='simple')

def redact_pii(df, input_column, pii_groups_to_mask):
    """
    Function to redact personally identifiable information (PII) from a DataFrame column using a specified PII NER model.

    Parameters:
    df: DataFrame containing the data to be processed.
    input_column: String specifying the column containing text to process.
    pii_groups_to_mask: List of PII entity groups to mask (e.g., ['SSN', 'CREDIT_CARD', 'PHONE_NUMBER']).

    Returns:
    DataFrame with an additional column 'pii_masked_transcriptions' containing the PII-redacted text.
    """
    def redact_text(text):
        pii_entities = pii_pipeline(text)
        pii_masked_text = text
        offset = 0
        for entity in sorted(pii_entities, key=lambda x: x['start']):
            if entity['entity_group'].lower() in pii_groups_to_mask:
                start = entity['start'] + offset
                end = entity['end'] + offset
                entity_tag = entity['entity_group']
                masked_word = f"[{entity_tag}]"
                pii_masked_text = pii_masked_text[:start] + masked_word + pii_masked_text[end:]
                offset += len(masked_word) - (end - start)

        return pii_masked_text

    # Apply the redaction function to each row in the specified column
    df['pii_masked_transcriptions_v2'] = df[input_column].apply(redact_text)
    return df

pii_groups_to_mask = ['City', 'State']
redacted_df = redact_pii(df, 'med_masked_transcriptions_biomedicalNER', pii_groups_to_mask)
print(redacted_df)
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /home/ray/.cache/huggingface/token
# Login successful
# config.json:   0%|          | 0.00/6.01k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/436M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.19k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
#       Unnamed: 0         medical_specialty  \
# 0              0                 Neurology
# 1              1  Cardiovascular/Pulmonary
# 2              2                   Urology
# 3              3                   Urology
# 4              4                   Urology
# ...          ...                       ...
# 2011        2011  Cardiovascular/Pulmonary
# 2012        2012  Cardiovascular/Pulmonary
# 2013        2013  Cardiovascular/Pulmonary
# 2014        2014  Cardiovascular/Pulmonary
# 2015        2015  Cardiovascular/Pulmonary
#
#                                           transcription  \
# 0     CC:, Confusion and slurred speech.,HX , (prima...
# 1     PREOPERATIVE DIAGNOSES,Airway obstruction seco...
# 2     PROCEDURE: , Elective male sterilization via b...
# 3     DESCRIPTION:,  The patient was placed in the s...
# 4     PREOPERATIVE DIAGNOSIS: , Voluntary sterility....
# ...                                                 ...
# 2011  INDICATION: , Chest pain.,TYPE OF TEST: , Aden...
# 2012  CHIEF COMPLAINT: , Chest pain.,HISTORY OF PRES...
# 2013  HISTORY OF PRESENT ILLNESS: , The patient is a...
# 2014  HISTORY OF PRESENT ILLNESS: , Mr. ABC is a 60-...
# 2015  REASON FOR CONSULTATION:  ,Abnormal echocardio...
#
#                                    age_related_sentence  \
# 0     HX , (primarily obtained from boyfriend): This...
# 1     INDICATIONS FOR SURGERY,The patient is a 50-ye...
# 2     PROCEDURE: , Elective male sterilization via b...
# 3     DESCRIPTION:, The patient was placed in the su...
# 4     INDICATIONS FOR PROCEDURE:  ,A gentleman who i...
# ...                                                 ...
# 2011  TYPE OF TEST: , Adenosine with nuclear scan as...
# 2012  HISTORY OF PRESENT ILLNESS:,  The patient is a...
# 2013  HISTORY OF PRESENT ILLNESS: , The patient is a...
# 2014  ABC is a 60-year-old gentleman who had a marke...
# 2015  HISTORY OF PRESENT ILLNESS: ,The patient is an...
#
#                                          extracted_text  word_count  \
# 0     (primarily obtained from boyfriend): This 31 y...          43
# 1     The patient is a 50-year-old white male with h...          72
# 2     Elective male sterilization via bilateral vase...          43
# 3     The patient was placed in the supine position ...          44
# 4     A gentleman who is here today requesting volun...          63
# ...                                                 ...         ...
# 2011  Adenosine with nuclear scan as the patient una...          41
# 2012  The patient is a 40-year-old white male who pr...          46
# 2013  HISTORY OF PRESENT ILLNESS: , The patient is a...          62
# 2014  ABC is a 60-year-old gentleman who had a marke...         119
# 2015  HISTORY OF PRESENT ILLNESS: ,The patient is an...          45
#
#                               med_masked_transcriptions  \
# 0     (primarily obtained from boyfriend): This[AGE]...
# 1     The patient is a[AGE] white[SEX] with history ...
# 2     Elective male sterilization via bilateral vase...
# 3     The patient was placed in the supine position ...
# 4     A gentleman who is here today requesting volun...
# ...                                                 ...
# 2011  Adenosine with nuclear scan as the patient una...
# 2012  The patient is a[AGE] white[SEX] who presents ...
# 2013  HISTORY OF PRESENT ILLNESS: , The patient is a...
# 2014  ABC is a[AGE][SEX] who had a[LAB_VALUE][LAB_VA...
# 2015  HISTORY OF PRESENT ILLNESS: ,The patient is an...
#
#                               pii_masked_transcriptions  \
# 0     (primarily obtained from boyfriend): This[AGE]...
# 1     The patient is a[AGE] white[SEX] with history ...
# 2     Elective male sterilization via bilateral vase...
# 3     The patient was placed in the supine position ...
# 4     A gentleman who is here today requesting volun...
# ...                                                 ...
# 2011  Adenosine with nuclear scan as the patient una...
# 2012  The patient is a[AGE] white[SEX] who presents ...
# 2013  HISTORY OF PRESENT ILLNESS: , The patient is a...
# 2014  ABC is a[AGE][SEX] who had a[LAB_VALUE][LAB_VA...
# 2015  HISTORY OF PRESENT ILLNESS: ,The patient is an...
#
#                  synthetic_sentence_nodp_temp0.6_topk50  \
# 0     [BOS]Neurology[SEP]The patient is a 55-year-ol...
# 1     [BOS]Cardiovascular/Pulmonary[SEP]This is a 74...
# 2     [BOS]Urology[SEP]HISTORY OF PRESENT ILLNESS:, ...
# 3     [BOS]Urology[SEP]The patient was brought to th...
# 4     [BOS]Urology[SEP]The patient was brought to th...
# ...                                                 ...
# 2011  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2012  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2013  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2014  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
# 2015  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...
#
#                   synthetic_sentence_eps16_temp1_topk50  ... combined_2_AGE  \
# 0     [BOS]Neurology[SEP]The patient is a 38-year-ol...  ...            NaN
# 1     [BOS]Cardiovascular/Pulmonary[SEP]The patient ...  ...            AGE
# 2     [BOS]Urology[SEP]Cardiovascular/Pulmonary[SEP:...  ...            AGE
# 3     [BOS]Urology[SEP]The patient with a history of...  ...            NaN
# 4     [BOS]Urology[SEP]HISTORY OF THE PROCEDURE:, Th...  ...            NaN
# ...                                                 ...  ...            ...
# 2011  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...  ...            NaN
# 2012  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...  ...            AGE
# 2013  [BOS]Cardiovascular/Pulmonary[SEP]This is a 5-...  ...            AGE
# 2014  [BOS]Cardiovascular/Pulmonary[SEP]The patient ...  ...            AGE
# 2015  [BOS]Cardiovascular/Pulmonary[SEP]This is a 35...  ...            AGE
#
#                             combined_1_DISEASE_DISORDER  \
# 0     DISEASE_DISORDER DISEASE_DISORDER DISEASE_DISO...
# 1                                      DISEASE_DISORDER
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2011                                                NaN
# 2012                                                NaN
# 2013                                   DISEASE_DISORDER
# 2014                                   DISEASE_DISORDER
# 2015  DISEASE_DISORDER DISEASE_DISORDER DISEASE_DISO...
#
#                             combined_2_DISEASE_DISORDER  \
# 0                                      DISEASE_DISORDER
# 1     DISEASE_DISORDER DISEASE_DISORDER DISEASE_DISO...
# 2                                      DISEASE_DISORDER
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2011                                                NaN
# 2012                                                NaN
# 2013                                                NaN
# 2014                                   DISEASE_DISORDER
# 2015                  DISEASE_DISORDER DISEASE_DISORDER
#
#                                    combined_1_LAB_VALUE  \
# 0                                                   NaN
# 1                                   LAB_VALUE LAB_VALUE
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2011  LAB_VALUE LAB_VALUE LAB_VALUE LAB_VALUE LAB_VA...
# 2012                                                NaN
# 2013                                                NaN
# 2014  LAB_VALUE LAB_VALUE LAB_VALUE LAB_VALUE LAB_VA...
# 2015                                                NaN
#
#                                    combined_2_LAB_VALUE combined_1_SEX  \
# 0                                             LAB_VALUE            NaN
# 1                                                   NaN            SEX
# 2                                                   NaN            SEX
# 3                                                   NaN            NaN
# 4                                                   NaN            NaN
# ...                                                 ...            ...
# 2011  LAB_VALUE LAB_VALUE LAB_VALUE LAB_VALUE LAB_VA...            NaN
# 2012                                                NaN            SEX
# 2013                                                NaN            SEX
# 2014  LAB_VALUE LAB_VALUE LAB_VALUE LAB_VALUE LAB_VALUE            SEX
# 2015                                                NaN            SEX
#
#        combined_2_SEX                            combined_1_SIGN_SYMPTOM  \
# 0                 NaN  SIGN_SYMPTOM SIGN_SYMPTOM SIGN_SYMPTOM SIGN_SY...
# 1                 SEX                                       SIGN_SYMPTOM
# 2     SEX SEX SEX SEX             SIGN_SYMPTOM SIGN_SYMPTOM SIGN_SYMPTOM
# 3                 NaN                                                NaN
# 4                 SEX                                                NaN
# ...               ...                                                ...
# 2011              NaN                                                NaN
# 2012              SEX                          SIGN_SYMPTOM SIGN_SYMPTOM
# 2013              SEX                                       SIGN_SYMPTOM
# 2014              SEX  SIGN_SYMPTOM SIGN_SYMPTOM SIGN_SYMPTOM SIGN_SY...
# 2015              SEX             SIGN_SYMPTOM SIGN_SYMPTOM SIGN_SYMPTOM
#
#                                 combined_2_SIGN_SYMPTOM  \
# 0                SIGN_SYMPTOM SIGN_SYMPTOM SIGN_SYMPTOM
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2011                                       SIGN_SYMPTOM
# 2012                          SIGN_SYMPTOM SIGN_SYMPTOM
# 2013                                       SIGN_SYMPTOM
# 2014  SIGN_SYMPTOM SIGN_SYMPTOM SIGN_SYMPTOM SIGN_SY...
# 2015  SIGN_SYMPTOM SIGN_SYMPTOM SIGN_SYMPTOM SIGN_SY...
#
#                            pii_masked_transcriptions_v2
# 0     (primarily obtained from boyfriend): This [Lab...
# 1     The patient is a [Age] white [Sex] with histor...
# 2     Elective [Sex] sterilization via bilateral vas...
# 3     The patient was placed in the supine position ...
# 4     A [Sex] who is here today requesting voluntary...
# ...                                                 ...
# 2011  Adenosine with nuclear scan as the patient [Si...
# 2012  The patient is a [Age] white [Sex] who present...
# 2013  HISTORY OF PRESENT ILLNESS: , The patient is a...
# 2014  ABC is a [Age] [Sex] who had a markedly [Lab_v...
# 2015  HISTORY OF PRESENT ILLNESS: ,The patient is an...
#
# [2016 rows x 35 columns]

# %% [markdown]
# ## Check Difference in Distributions

# %%
import re
import pandas as pd
import matplotlib.pyplot as plt

# Function to extract entities and their positions from masked text
def extract_entities_with_positions(masked_text):
    if pd.isna(masked_text):
        return []
    return [(m.group(1).upper(), m.start()) for m in re.finditer(r'\[([A-Za-z_]+)\]', masked_text)]

# Function to apply heuristic corrections for common errors
def heuristic_corrections(entities):
    corrected_entities = []
    for entity, pos in entities:
        if entity in ['AGE', 'Age']:
            corrected_entities.append(('AGE', pos))
        elif entity in ['SEX', 'Sex']:
            corrected_entities.append(('SEX', pos))
        elif entity in ['DISEASE_DISORDER', 'Disease_Disorder']:
            corrected_entities.append(('DISEASE_DISORDER', pos))
        elif entity in ['SIGN_SYMPTOM', 'Sign_Symptom']:
            corrected_entities.append(('SIGN_SYMPTOM', pos))
        elif entity in ['LAB_VALUE', 'Lab_Value']:
            corrected_entities.append(('LAB_VALUE', pos))
        elif entity in ['CITY', 'City']:
            corrected_entities.append(('CITY', pos))
        elif entity in ['STATE', 'State']:
            corrected_entities.append(('STATE', pos))
        else:
            corrected_entities.append((entity, pos))
    return corrected_entities

# Function to plot histograms of entities
def plot_entity_histograms(df, column1, column2):
    df['entities_1'] = df[column1].apply(lambda x: heuristic_corrections(extract_entities_with_positions(x)))
    df['entities_2'] = df[column2].apply(lambda x: heuristic_corrections(extract_entities_with_positions(x)))

    all_entities_1 = [(entity, pos) for sublist in df['entities_1'] for entity, pos in sublist]
    all_entities_2 = [(entity, pos) for sublist in df['entities_2'] for entity, pos in sublist]

    df_entities_1 = pd.DataFrame(all_entities_1, columns=['Entity', 'Position'])
    df_entities_2 = pd.DataFrame(all_entities_2, columns=['Entity', 'Position'])

    entity_types = df_entities_1['Entity'].unique()

    colors = {
        'AGE': ('#FFA500', '#FF4500'),  # light orange, dark orange
        'SEX': ('#ADD8E6', '#0000FF'),  # light blue, dark blue
        'DISEASE_DISORDER': ('#FFC0CB', '#FF0000'),  # light red, dark red
        'SIGN_SYMPTOM': ('#98FB98', '#008000'),  # light green, dark green
        'LAB_VALUE': ('#D3D3D3', '#A9A9A9'),  # light gray, dark gray
        'CITY': ('#FFD700', '#FFA500'),  # light gold, dark gold
        'STATE': ('#87CEEB', '#4682B4'),  # light sky blue, steel blue
    }

    # Plot histograms for each entity type
    for entity_type in entity_types:
        fig, ax = plt.subplots(figsize=(12, 8))

        positions_1 = df_entities_1[df_entities_1['Entity'] == entity_type]['Position']
        positions_2 = df_entities_2[df_entities_2['Entity'] == entity_type]['Position']

        bins = range(0, max(positions_1.max() if not positions_1.empty else 0, 
                            positions_2.max() if not positions_2.empty else 0) + 10, 10)

        color_1, color_2 = colors.get(entity_type, ('#FFFFFF', '#000000'))  # Default to white and black if not found
        ax.hist(positions_1, bins=bins, color=color_1, alpha=0.6, label=f'{entity_type} (Model 1)', orientation='vertical')
        ax.hist(positions_2, bins=bins, color=color_2, alpha=0.6, label=f'{entity_type} (Model 2)', orientation='vertical')

        handles, labels = ax.get_legend_handles_labels()
        by_label = dict(zip(labels, handles))
        ax.legend(by_label.values(), by_label.keys())

        ax.set_xlabel('Position in Sentence')
        ax.set_ylabel('Count')
        ax.set_title(f'Histogram of {entity_type} Entity Distributions')
        plt.show()

# Plot histograms for each entity type
plot_entity_histograms(df, 'pii_masked_transcriptions', 'pii_masked_transcriptions_v2')

# %% [markdown]
# ## Check Normality

# %%
import re
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import shapiro, kstest, anderson
import statsmodels.api as sm

# Function to extract entities and their positions from masked text
def extract_entities_with_positions(masked_text):
    if pd.isna(masked_text):
        return []
    return [(m.group(1).upper(), m.start()) for m in re.finditer(r'\[([A-Za-z_]+)\]', masked_text)]

# Function to apply heuristic corrections for common errors
def heuristic_corrections(entities):
    corrected_entities = []
    for entity, pos in entities:
        if entity in ['AGE', 'Age']:
            corrected_entities.append(('AGE', pos))
        elif entity in ['SEX', 'Sex']:
            corrected_entities.append(('SEX', pos))
        elif entity in ['DISEASE_DISORDER', 'Disease_Disorder']:
            corrected_entities.append(('DISEASE_DISORDER', pos))
        elif entity in ['SIGN_SYMPTOM', 'Sign_Symptom']:
            corrected_entities.append(('SIGN_SYMPTOM', pos))
        elif entity in ['LAB_VALUE', 'Lab_Value']:
            corrected_entities.append(('LAB_VALUE', pos))
        elif entity in ['CITY', 'City']:
            corrected_entities.append(('CITY', pos))
        elif entity in ['STATE', 'State']:
            corrected_entities.append(('STATE', pos))
        else:
            corrected_entities.append((entity, pos))
    return corrected_entities

# Function to check normality of the positions of entities
def check_normality_all_entities(df, column):
    df['entities'] = df[column].apply(lambda x: heuristic_corrections(extract_entities_with_positions(x)))
    all_entities = [(entity, pos) for sublist in df['entities'] for entity, pos in sublist]

    if not all_entities:
        print("No entities found.")
        return

    df_entities = pd.DataFrame(all_entities, columns=['Entity', 'Position'])
    entity_types = df_entities['Entity'].unique()

    normality_results = {}

    for entity_type in entity_types:
        positions = df_entities[df_entities['Entity'] == entity_type]['Position']

        # Plot histogram
        plt.figure(figsize=(12, 6))
        sns.histplot(positions, kde=True)
        plt.title(f'Histogram of {entity_type} Positions')
        plt.xlabel('Position in Sentence')
        plt.ylabel('Frequency')
        plt.show()

        # Q-Q plot
        plt.figure(figsize=(12, 6))
        sm.qqplot(positions, line='s')
        plt.title(f'Q-Q Plot of {entity_type} Positions')
        plt.show()

        # Shapiro-Wilk Test
        shapiro_stat, shapiro_p = shapiro(positions)
        print(f'Shapiro-Wilk Test for {entity_type}: Statistic={shapiro_stat}, p-value={shapiro_p}')

        # Kolmogorov-Smirnov Test
        ks_stat, ks_p = kstest(positions, 'norm')
        print(f'Kolmogorov-Smirnov Test for {entity_type}: Statistic={ks_stat}, p-value={ks_p}')

        # Anderson-Darling Test
        ad_result = anderson(positions)
        print(f'Anderson-Darling Test for {entity_type}:')
        print(f'Statistic: {ad_result.statistic}')
        for i in range(len(ad_result.critical_values)):
            cv, sig_lvl = ad_result.critical_values[i], ad_result.significance_level[i]
            print(f'  Critical value: {cv}, Significance level: {sig_lvl}%')

        normality_results[entity_type] = {
            'Shapiro-Wilk': (shapiro_stat, shapiro_p),
            'Kolmogorov-Smirnov': (ks_stat, ks_p),
            'Anderson-Darling': (ad_result.statistic, ad_result.critical_values, ad_result.significance_level)
        }

    return normality_results


# Check normality for all entity types
normality_results = check_normality_all_entities(df, 'pii_masked_transcriptions')

# Print normality results
for entity, results in normality_results.items():
    print(f"\nNormality Results for {entity}:")
    print(f"Shapiro-Wilk Test: Statistic={results['Shapiro-Wilk'][0]}, p-value={results['Shapiro-Wilk'][1]}")
    print(f"Kolmogorov-Smirnov Test: Statistic={results['Kolmogorov-Smirnov'][0]}, p-value={results['Kolmogorov-Smirnov'][1]}")
    ad_stat, ad_critical, ad_significance = results['Anderson-Darling']
    print(f"Anderson-Darling Test: Statistic={ad_stat}")
    for cv, sig_lvl in zip(ad_critical, ad_significance):
        print(f"  Critical value: {cv}, Significance level: {sig_lvl}%")
# Out:
# Shapiro-Wilk Test for AGE: Statistic=0.6104447841644287, p-value=0.0
# Kolmogorov-Smirnov Test for AGE: Statistic=0.9441068024009678, p-value=0.0
# Anderson-Darling Test for AGE:
# Statistic: 160.87603519358458
#   Critical value: 0.574, Significance level: 15.0%
#   Critical value: 0.654, Significance level: 10.0%
#   Critical value: 0.785, Significance level: 5.0%
#   Critical value: 0.915, Significance level: 2.5%
#   Critical value: 1.089, Significance level: 1.0%
# Shapiro-Wilk Test for DISEASE_DISORDER: Statistic=0.9233846068382263, p-value=1.6128628849214377e-30
# Kolmogorov-Smirnov Test for DISEASE_DISORDER: Statistic=0.9958970819388284, p-value=0.0
# Anderson-Darling Test for DISEASE_DISORDER:
# Statistic: 32.45662474663504
#   Critical value: 0.575, Significance level: 15.0%
#   Critical value: 0.655, Significance level: 10.0%
#   Critical value: 0.785, Significance level: 5.0%
#   Critical value: 0.916, Significance level: 2.5%
#   Critical value: 1.09, Significance level: 1.0%
# Shapiro-Wilk Test for SIGN_SYMPTOM: Statistic=0.9467851519584656, p-value=1.4102139403876125e-34
# Kolmogorov-Smirnov Test for SIGN_SYMPTOM: Statistic=0.9978293389588458, p-value=0.0
# Anderson-Darling Test for SIGN_SYMPTOM:
# Statistic: 29.830166265805474
#   Critical value: 0.575, Significance level: 15.0%
#   Critical value: 0.655, Significance level: 10.0%
#   Critical value: 0.786, Significance level: 5.0%
#   Critical value: 0.917, Significance level: 2.5%
#   Critical value: 1.091, Significance level: 1.0%
# Shapiro-Wilk Test for SEX: Statistic=0.6484044790267944, p-value=6.788730540268009e-41
# Kolmogorov-Smirnov Test for SEX: Statistic=0.9989551575322297, p-value=0.0
# Anderson-Darling Test for SEX:
# Statistic: 95.3603653716084
#   Critical value: 0.574, Significance level: 15.0%
#   Critical value: 0.653, Significance level: 10.0%
#   Critical value: 0.784, Significance level: 5.0%
#   Critical value: 0.914, Significance level: 2.5%
#   Critical value: 1.088, Significance level: 1.0%
# Shapiro-Wilk Test for STATE: Statistic=0.9258774518966675, p-value=0.009428823366761208
# Kolmogorov-Smirnov Test for STATE: Statistic=1.0, p-value=0.0
# Anderson-Darling Test for STATE:
# Statistic: 0.8680582346334376
#   Critical value: 0.533, Significance level: 15.0%
#   Critical value: 0.607, Significance level: 10.0%
#   Critical value: 0.728, Significance level: 5.0%
#   Critical value: 0.849, Significance level: 2.5%
#   Critical value: 1.01, Significance level: 1.0%
# Shapiro-Wilk Test for LAB_VALUE: Statistic=0.9678024649620056, p-value=1.0159260992138527e-13
# Kolmogorov-Smirnov Test for LAB_VALUE: Statistic=0.9958246346542525, p-value=0.0
# Anderson-Darling Test for LAB_VALUE:
# Statistic: 2.7723028233031073
#   Critical value: 0.574, Significance level: 15.0%
#   Critical value: 0.653, Significance level: 10.0%
#   Critical value: 0.784, Significance level: 5.0%
#   Critical value: 0.914, Significance level: 2.5%
#   Critical value: 1.087, Significance level: 1.0%
# Shapiro-Wilk Test for CITY: Statistic=0.9056148529052734, p-value=0.0016266177408397198
# Kolmogorov-Smirnov Test for CITY: Statistic=1.0, p-value=0.0
# Anderson-Darling Test for CITY:
# Statistic: 0.9271791113262751
#   Critical value: 0.534, Significance level: 15.0%
#   Critical value: 0.609, Significance level: 10.0%
#   Critical value: 0.73, Significance level: 5.0%
#   Critical value: 0.852, Significance level: 2.5%
#   Critical value: 1.013, Significance level: 1.0%
#
# Normality Results for AGE:
# Shapiro-Wilk Test: Statistic=0.6104447841644287, p-value=0.0
# Kolmogorov-Smirnov Test: Statistic=0.9441068024009678, p-value=0.0
# Anderson-Darling Test: Statistic=160.87603519358458
#   Critical value: 0.574, Significance level: 15.0%
#   Critical value: 0.654, Significance level: 10.0%
#   Critical value: 0.785, Significance level: 5.0%
#   Critical value: 0.915, Significance level: 2.5%
#   Critical value: 1.089, Significance level: 1.0%
#
# Normality Results for DISEASE_DISORDER:
# Shapiro-Wilk Test: Statistic=0.9233846068382263, p-value=1.6128628849214377e-30
# Kolmogorov-Smirnov Test: Statistic=0.9958970819388284, p-value=0.0
# Anderson-Darling Test: Statistic=32.45662474663504
#   Critical value: 0.575, Significance level: 15.0%
#   Critical value: 0.655, Significance level: 10.0%
#   Critical value: 0.785, Significance level: 5.0%
#   Critical value: 0.916, Significance level: 2.5%
#   Critical value: 1.09, Significance level: 1.0%
#
# Normality Results for SIGN_SYMPTOM:
# Shapiro-Wilk Test: Statistic=0.9467851519584656, p-value=1.4102139403876125e-34
# Kolmogorov-Smirnov Test: Statistic=0.9978293389588458, p-value=0.0
# Anderson-Darling Test: Statistic=29.830166265805474
#   Critical value: 0.575, Significance level: 15.0%
#   Critical value: 0.655, Significance level: 10.0%
#   Critical value: 0.786, Significance level: 5.0%
#   Critical value: 0.917, Significance level: 2.5%
#   Critical value: 1.091, Significance level: 1.0%
#
# Normality Results for SEX:
# Shapiro-Wilk Test: Statistic=0.6484044790267944, p-value=6.788730540268009e-41
# Kolmogorov-Smirnov Test: Statistic=0.9989551575322297, p-value=0.0
# Anderson-Darling Test: Statistic=95.3603653716084
#   Critical value: 0.574, Significance level: 15.0%
#   Critical value: 0.653, Significance level: 10.0%
#   Critical value: 0.784, Significance level: 5.0%
#   Critical value: 0.914, Significance level: 2.5%
#   Critical value: 1.088, Significance level: 1.0%
#
# Normality Results for STATE:
# Shapiro-Wilk Test: Statistic=0.9258774518966675, p-value=0.009428823366761208
# Kolmogorov-Smirnov Test: Statistic=1.0, p-value=0.0
# Anderson-Darling Test: Statistic=0.8680582346334376
#   Critical value: 0.533, Significance level: 15.0%
#   Critical value: 0.607, Significance level: 10.0%
#   Critical value: 0.728, Significance level: 5.0%
#   Critical value: 0.849, Significance level: 2.5%
#   Critical value: 1.01, Significance level: 1.0%
#
# Normality Results for LAB_VALUE:
# Shapiro-Wilk Test: Statistic=0.9678024649620056, p-value=1.0159260992138527e-13
# Kolmogorov-Smirnov Test: Statistic=0.9958246346542525, p-value=0.0
# Anderson-Darling Test: Statistic=2.7723028233031073
#   Critical value: 0.574, Significance level: 15.0%
#   Critical value: 0.653, Significance level: 10.0%
#   Critical value: 0.784, Significance level: 5.0%
#   Critical value: 0.914, Significance level: 2.5%
#   Critical value: 1.087, Significance level: 1.0%
#
# Normality Results for CITY:
# Shapiro-Wilk Test: Statistic=0.9056148529052734, p-value=0.0016266177408397198
# Kolmogorov-Smirnov Test: Statistic=1.0, p-value=0.0
# Anderson-Darling Test: Statistic=0.9271791113262751
#   Critical value: 0.534, Significance level: 15.0%
#   Critical value: 0.609, Significance level: 10.0%
#   Critical value: 0.73, Significance level: 5.0%
#   Critical value: 0.852, Significance level: 2.5%
#   Critical value: 1.013, Significance level: 1.0%

# %% [markdown]
# ## Mann Whitney to test if there is significant statistical difference
#
# The results from the Shapiro-Wilk Test, Kolmogorov-Smirnov Test, and Anderson-Darling Test consistently indicate that the data is not normally distributed. Therefore, non-parametric tests such as the Mann-Whitney U test are appropriate for comparing the distributions of entities between the two NER models. Additionally, the data is independent.

# %%
import re
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import mannwhitneyu

# Function to extract entities and their positions from masked text
def extract_entities_with_positions(masked_text):
    if pd.isna(masked_text):
        return []
    return [(m.group(1).upper(), m.start()) for m in re.finditer(r'\[([A-Za-z_]+)\]', masked_text)]

# Function to apply heuristic corrections for common errors
def heuristic_corrections(entities):
    corrected_entities = []
    for entity, pos in entities:
        if entity in ['AGE', 'Age']:
            corrected_entities.append(('AGE', pos))
        elif entity in ['SEX', 'Sex']:
            corrected_entities.append(('SEX', pos))
        elif entity in ['DISEASE_DISORDER', 'Disease_Disorder']:
            corrected_entities.append(('DISEASE_DISORDER', pos))
        elif entity in ['SIGN_SYMPTOM', 'Sign_Symptom']:
            corrected_entities.append(('SIGN_SYMPTOM', pos))
        elif entity in ['LAB_VALUE', 'Lab_Value']:
            corrected_entities.append(('LAB_VALUE', pos))
        elif entity in ['CITY', 'City']:
            corrected_entities.append(('CITY', pos))
        elif entity in ['STATE', 'State']:
            corrected_entities.append(('STATE', pos))
        else:
            corrected_entities.append((entity, pos))
    return corrected_entities

# Function to perform Mann-Whitney U test for each entity type
def perform_mann_whitney_tests(df, column1, column2):
    df['entities_1'] = df[column1].apply(lambda x: heuristic_corrections(extract_entities_with_positions(x)))
    df['entities_2'] = df[column2].apply(lambda x: heuristic_corrections(extract_entities_with_positions(x)))

    all_entities_1 = [(entity, pos) for sublist in df['entities_1'] for entity, pos in sublist]
    all_entities_2 = [(entity, pos) for sublist in df['entities_2'] for entity, pos in sublist]

    df_entities_1 = pd.DataFrame(all_entities_1, columns=['Entity', 'Position'])
    df_entities_2 = pd.DataFrame(all_entities_2, columns=['Entity', 'Position'])

    entity_types = df_entities_1['Entity'].unique()

    mann_whitney_results = {}

    for entity_type in entity_types:
        positions_1 = df_entities_1[df_entities_1['Entity'] == entity_type]['Position']
        positions_2 = df_entities_2[df_entities_2['Entity'] == entity_type]['Position']

        if positions_1.empty or positions_2.empty:
            print(f"Skipping Mann-Whitney U test for {entity_type} due to one of the columns being empty.")
            continue

        u_stat, p_value = mannwhitneyu(positions_1, positions_2, alternative='two-sided')  # Perform Mann-Whitney U test
        mann_whitney_results[entity_type] = (u_stat, p_value)

    return mann_whitney_results

# Perform Mann-Whitney U tests for each entity type
mann_whitney_results = perform_mann_whitney_tests(df, 'pii_masked_transcriptions', 'pii_masked_transcriptions_v2')

# Print the Mann-Whitney U test results
print("Mann-Whitney U Test Results for Each Entity Type:")
for entity, (u_stat, p_value) in mann_whitney_results.items():
    print(f"{entity}: U-statistic = {u_stat}, p-value = {p_value}")
# Out:
# Skipping Mann-Whitney U test for STATE due to one of the columns being empty.
# Skipping Mann-Whitney U test for CITY due to one of the columns being empty.
# Mann-Whitney U Test Results for Each Entity Type:
# AGE: U-statistic = 584652.5, p-value = 2.3469652546093185e-08
# DISEASE_DISORDER: U-statistic = 1160959.5, p-value = 0.0005512781154835075
# SIGN_SYMPTOM: U-statistic = 5605211.0, p-value = 0.3263836841985869
# SEX: U-statistic = 416595.5, p-value = 3.1433758206076187e-07
# LAB_VALUE: U-statistic = 586027.5, p-value = 0.00011301644841588341
